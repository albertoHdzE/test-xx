# %% [markdown]
# # Time series forecasting (airline passengers)

# %%
# Full code:
# https://github.com/pycaret/pycaret/blob/master/tutorials/Tutorial%20-%20Binary%20Classification.ipynb

# %%
### loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('airline')
# plot the dataset
data.plot()
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64
# <Axes: xlabel='Period'>

# %%
# import pycaret time series and init setup
from pycaret.time_series import *
s = setup(data, fh = 3, session_id = 123)
# Out:
# <style type="text/css">
# #T_1236c_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1236c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1236c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1236c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1236c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1236c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1236c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1236c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1236c_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1236c_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_1236c_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1236c_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_1236c_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1236c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_1236c_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1236c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_1236c_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1236c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_1236c_row6_col1" class="data row6 col1" >(141, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1236c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_1236c_row7_col1" class="data row7 col1" >(3, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1236c_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_1236c_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1236c_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_1236c_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1236c_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_1236c_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1236c_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_1236c_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1236c_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_1236c_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1236c_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_1236c_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1236c_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_1236c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1236c_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_1236c_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1236c_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_1236c_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1236c_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_1236c_row17_col1" class="data row17 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1236c_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_1236c_row18_col1" class="data row18 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1236c_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_1236c_row19_col1" class="data row19 col1" >[48, 36, 11]</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1236c_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_1236c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1236c_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_1236c_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1236c_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_1236c_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1236c_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_1236c_row23_col1" class="data row23 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1236c_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_1236c_row24_col1" class="data row24 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1236c_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_1236c_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1236c_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_1236c_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1236c_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_1236c_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1236c_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_1236c_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_1236c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1236c_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_1236c_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
# import TSForecastingExperiment and init the class
from pycaret.time_series import TSForecastingExperiment
exp = TSForecastingExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.time_series.forecasting.oop.TSForecastingExperiment

# %%
# init setup on exp
exp.setup(data, fh = 3, session_id = 123)
# Out:
# <style type="text/css">
# #T_bd33c_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bd33c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd33c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bd33c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd33c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd33c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_bd33c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd33c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bd33c_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd33c_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_bd33c_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd33c_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_bd33c_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd33c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_bd33c_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd33c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_bd33c_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd33c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_bd33c_row6_col1" class="data row6 col1" >(141, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bd33c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_bd33c_row7_col1" class="data row7 col1" >(3, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bd33c_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_bd33c_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bd33c_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_bd33c_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bd33c_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_bd33c_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bd33c_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_bd33c_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bd33c_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_bd33c_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bd33c_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_bd33c_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bd33c_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_bd33c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bd33c_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_bd33c_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bd33c_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_bd33c_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bd33c_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_bd33c_row17_col1" class="data row17 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bd33c_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_bd33c_row18_col1" class="data row18 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bd33c_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_bd33c_row19_col1" class="data row19 col1" >[48, 36, 11]</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bd33c_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_bd33c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bd33c_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_bd33c_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_bd33c_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_bd33c_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_bd33c_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_bd33c_row23_col1" class="data row23 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_bd33c_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_bd33c_row24_col1" class="data row24 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_bd33c_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_bd33c_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_bd33c_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_bd33c_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_bd33c_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_bd33c_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_bd33c_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_bd33c_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_bd33c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_bd33c_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_bd33c_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
# check statistical tests on original data
check_stats()
# Out:
#             Test   Test Name         Data             Property  \
# 0        Summary  Statistics  Transformed               Length
# 1        Summary  Statistics  Transformed     # Missing Values
# 2        Summary  Statistics  Transformed                 Mean
# 3        Summary  Statistics  Transformed               Median
# 4        Summary  Statistics  Transformed   Standard Deviation
# 5        Summary  Statistics  Transformed             Variance
# 6        Summary  Statistics  Transformed             Kurtosis
# 7        Summary  Statistics  Transformed             Skewness
# 8        Summary  Statistics  Transformed    # Distinct Values
# 9    White Noise   Ljung-Box  Transformed       Test Statictic
# 10   White Noise   Ljung-Box  Transformed       Test Statictic
# 11   White Noise   Ljung-Box  Transformed              p-value
# 12   White Noise   Ljung-Box  Transformed              p-value
# 13   White Noise   Ljung-Box  Transformed          White Noise
# 14   White Noise   Ljung-Box  Transformed          White Noise
# 15  Stationarity         ADF  Transformed         Stationarity
# 16  Stationarity         ADF  Transformed              p-value
# 17  Stationarity         ADF  Transformed       Test Statistic
# 18  Stationarity         ADF  Transformed    Critical Value 1%
# 19  Stationarity         ADF  Transformed    Critical Value 5%
# 20  Stationarity         ADF  Transformed   Critical Value 10%
# 21  Stationarity        KPSS  Transformed   Trend Stationarity
# 22  Stationarity        KPSS  Transformed              p-value
# 23  Stationarity        KPSS  Transformed       Test Statistic
# 24  Stationarity        KPSS  Transformed   Critical Value 10%
# 25  Stationarity        KPSS  Transformed    Critical Value 5%
# 26  Stationarity        KPSS  Transformed  Critical Value 2.5%
# 27  Stationarity        KPSS  Transformed    Critical Value 1%
# 28     Normality     Shapiro  Transformed            Normality
# 29     Normality     Shapiro  Transformed              p-value
#
#                      Setting         Value
# 0                                    144.0
# 1                                      0.0
# 2                               280.298611
# 3                                    265.5
# 4                               119.966317
# 5                             14391.917201
# 6                                -0.364942
# 7                                  0.58316
# 8                                    118.0
# 9   {'alpha': 0.05, 'K': 24}   1606.083817
# 10  {'alpha': 0.05, 'K': 48}   1933.155822
# 11  {'alpha': 0.05, 'K': 24}           0.0
# 12  {'alpha': 0.05, 'K': 48}           0.0
# 13  {'alpha': 0.05, 'K': 24}           0.0
# 14  {'alpha': 0.05, 'K': 48}           0.0
# 15           {'alpha': 0.05}         False
# 16           {'alpha': 0.05}       0.99188
# 17           {'alpha': 0.05}      0.815369
# 18           {'alpha': 0.05}     -3.481682
# 19           {'alpha': 0.05}     -2.884042
# 20           {'alpha': 0.05}      -2.57877
# 21           {'alpha': 0.05}          True
# 22           {'alpha': 0.05}           0.1
# 23           {'alpha': 0.05}       0.09615
# 24           {'alpha': 0.05}         0.119
# 25           {'alpha': 0.05}         0.146
# 26           {'alpha': 0.05}         0.176
# 27           {'alpha': 0.05}         0.216
# 28           {'alpha': 0.05}         False
# 29           {'alpha': 0.05}      0.000068

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_ad7f4 th {
#   text-align: left;
# }
# #T_ad7f4_row0_col0, #T_ad7f4_row1_col0, #T_ad7f4_row1_col1, #T_ad7f4_row1_col2, #T_ad7f4_row1_col3, #T_ad7f4_row1_col4, #T_ad7f4_row1_col5, #T_ad7f4_row1_col6, #T_ad7f4_row1_col7, #T_ad7f4_row2_col0, #T_ad7f4_row2_col1, #T_ad7f4_row2_col2, #T_ad7f4_row2_col3, #T_ad7f4_row2_col4, #T_ad7f4_row2_col5, #T_ad7f4_row2_col6, #T_ad7f4_row2_col7, #T_ad7f4_row3_col0, #T_ad7f4_row3_col1, #T_ad7f4_row3_col2, #T_ad7f4_row3_col3, #T_ad7f4_row3_col4, #T_ad7f4_row3_col5, #T_ad7f4_row3_col6, #T_ad7f4_row3_col7, #T_ad7f4_row4_col0, #T_ad7f4_row4_col1, #T_ad7f4_row4_col2, #T_ad7f4_row4_col3, #T_ad7f4_row4_col4, #T_ad7f4_row4_col5, #T_ad7f4_row4_col6, #T_ad7f4_row4_col7, #T_ad7f4_row5_col0, #T_ad7f4_row5_col1, #T_ad7f4_row5_col2, #T_ad7f4_row5_col3, #T_ad7f4_row5_col4, #T_ad7f4_row5_col5, #T_ad7f4_row5_col6, #T_ad7f4_row5_col7, #T_ad7f4_row6_col0, #T_ad7f4_row6_col1, #T_ad7f4_row6_col2, #T_ad7f4_row6_col3, #T_ad7f4_row6_col4, #T_ad7f4_row6_col5, #T_ad7f4_row6_col6, #T_ad7f4_row6_col7, #T_ad7f4_row7_col0, #T_ad7f4_row7_col1, #T_ad7f4_row7_col2, #T_ad7f4_row7_col3, #T_ad7f4_row7_col4, #T_ad7f4_row7_col5, #T_ad7f4_row7_col6, #T_ad7f4_row7_col7, #T_ad7f4_row8_col0, #T_ad7f4_row8_col1, #T_ad7f4_row8_col2, #T_ad7f4_row8_col3, #T_ad7f4_row8_col4, #T_ad7f4_row8_col5, #T_ad7f4_row8_col6, #T_ad7f4_row8_col7, #T_ad7f4_row9_col0, #T_ad7f4_row9_col1, #T_ad7f4_row9_col2, #T_ad7f4_row9_col3, #T_ad7f4_row9_col4, #T_ad7f4_row9_col5, #T_ad7f4_row9_col6, #T_ad7f4_row9_col7, #T_ad7f4_row10_col0, #T_ad7f4_row10_col1, #T_ad7f4_row10_col2, #T_ad7f4_row10_col3, #T_ad7f4_row10_col4, #T_ad7f4_row10_col5, #T_ad7f4_row10_col6, #T_ad7f4_row10_col7, #T_ad7f4_row11_col0, #T_ad7f4_row11_col1, #T_ad7f4_row11_col2, #T_ad7f4_row11_col3, #T_ad7f4_row11_col4, #T_ad7f4_row11_col5, #T_ad7f4_row11_col6, #T_ad7f4_row11_col7, #T_ad7f4_row12_col0, #T_ad7f4_row12_col1, #T_ad7f4_row12_col2, #T_ad7f4_row12_col3, #T_ad7f4_row12_col4, #T_ad7f4_row12_col5, #T_ad7f4_row12_col6, #T_ad7f4_row12_col7, #T_ad7f4_row13_col0, #T_ad7f4_row13_col1, #T_ad7f4_row13_col2, #T_ad7f4_row13_col3, #T_ad7f4_row13_col4, #T_ad7f4_row13_col5, #T_ad7f4_row13_col6, #T_ad7f4_row13_col7, #T_ad7f4_row14_col0, #T_ad7f4_row14_col1, #T_ad7f4_row14_col2, #T_ad7f4_row14_col3, #T_ad7f4_row14_col4, #T_ad7f4_row14_col5, #T_ad7f4_row14_col6, #T_ad7f4_row14_col7, #T_ad7f4_row15_col0, #T_ad7f4_row15_col1, #T_ad7f4_row15_col2, #T_ad7f4_row15_col3, #T_ad7f4_row15_col4, #T_ad7f4_row15_col5, #T_ad7f4_row15_col6, #T_ad7f4_row15_col7, #T_ad7f4_row16_col0, #T_ad7f4_row16_col1, #T_ad7f4_row16_col2, #T_ad7f4_row16_col3, #T_ad7f4_row16_col4, #T_ad7f4_row16_col5, #T_ad7f4_row16_col6, #T_ad7f4_row16_col7, #T_ad7f4_row17_col0, #T_ad7f4_row17_col1, #T_ad7f4_row17_col2, #T_ad7f4_row17_col3, #T_ad7f4_row17_col4, #T_ad7f4_row17_col5, #T_ad7f4_row17_col6, #T_ad7f4_row17_col7, #T_ad7f4_row18_col0, #T_ad7f4_row18_col1, #T_ad7f4_row18_col2, #T_ad7f4_row18_col3, #T_ad7f4_row18_col4, #T_ad7f4_row18_col5, #T_ad7f4_row18_col6, #T_ad7f4_row18_col7, #T_ad7f4_row19_col0, #T_ad7f4_row19_col1, #T_ad7f4_row19_col2, #T_ad7f4_row19_col3, #T_ad7f4_row19_col4, #T_ad7f4_row19_col5, #T_ad7f4_row19_col6, #T_ad7f4_row19_col7, #T_ad7f4_row20_col0, #T_ad7f4_row20_col1, #T_ad7f4_row20_col2, #T_ad7f4_row20_col3, #T_ad7f4_row20_col4, #T_ad7f4_row20_col5, #T_ad7f4_row20_col6, #T_ad7f4_row20_col7, #T_ad7f4_row21_col0, #T_ad7f4_row21_col1, #T_ad7f4_row21_col2, #T_ad7f4_row21_col3, #T_ad7f4_row21_col4, #T_ad7f4_row21_col5, #T_ad7f4_row21_col6, #T_ad7f4_row21_col7, #T_ad7f4_row22_col0, #T_ad7f4_row22_col1, #T_ad7f4_row22_col2, #T_ad7f4_row22_col3, #T_ad7f4_row22_col4, #T_ad7f4_row22_col5, #T_ad7f4_row22_col6, #T_ad7f4_row22_col7, #T_ad7f4_row23_col0, #T_ad7f4_row23_col1, #T_ad7f4_row23_col2, #T_ad7f4_row23_col3, #T_ad7f4_row23_col4, #T_ad7f4_row23_col5, #T_ad7f4_row23_col6, #T_ad7f4_row23_col7, #T_ad7f4_row24_col0, #T_ad7f4_row24_col1, #T_ad7f4_row24_col2, #T_ad7f4_row24_col3, #T_ad7f4_row24_col4, #T_ad7f4_row24_col5, #T_ad7f4_row24_col6, #T_ad7f4_row24_col7, #T_ad7f4_row25_col0, ...
#   text-align: left;
# }
# #T_ad7f4_row0_col1, #T_ad7f4_row0_col2, #T_ad7f4_row0_col3, #T_ad7f4_row0_col4, #T_ad7f4_row0_col5, #T_ad7f4_row0_col6, #T_ad7f4_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ad7f4_row0_col8, #T_ad7f4_row1_col8, #T_ad7f4_row2_col8, #T_ad7f4_row3_col8, #T_ad7f4_row4_col8, #T_ad7f4_row5_col8, #T_ad7f4_row6_col8, #T_ad7f4_row7_col8, #T_ad7f4_row8_col8, #T_ad7f4_row9_col8, #T_ad7f4_row10_col8, #T_ad7f4_row11_col8, #T_ad7f4_row12_col8, #T_ad7f4_row13_col8, #T_ad7f4_row14_col8, #T_ad7f4_row15_col8, #T_ad7f4_row16_col8, #T_ad7f4_row17_col8, #T_ad7f4_row18_col8, #T_ad7f4_row19_col8, #T_ad7f4_row20_col8, #T_ad7f4_row21_col8, #T_ad7f4_row22_col8, #T_ad7f4_row25_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ad7f4_row23_col8, #T_ad7f4_row24_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ad7f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad7f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ad7f4_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ad7f4_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ad7f4_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ad7f4_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ad7f4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ad7f4_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ad7f4_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_ad7f4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad7f4_level0_row0" class="row_heading level0 row0" >stlf</th>
#       <td id="T_ad7f4_row0_col0" class="data row0 col0" >STLF</td>
#       <td id="T_ad7f4_row0_col1" class="data row0 col1" >0.4136</td>
#       <td id="T_ad7f4_row0_col2" class="data row0 col2" >0.4530</td>
#       <td id="T_ad7f4_row0_col3" class="data row0 col3" >12.7373</td>
#       <td id="T_ad7f4_row0_col4" class="data row0 col4" >15.8272</td>
#       <td id="T_ad7f4_row0_col5" class="data row0 col5" >0.0262</td>
#       <td id="T_ad7f4_row0_col6" class="data row0 col6" >0.0261</td>
#       <td id="T_ad7f4_row0_col7" class="data row0 col7" >0.2016</td>
#       <td id="T_ad7f4_row0_col8" class="data row0 col8" >0.3700</td>
#     </tr>
#     <tr>
#       <th id="T_ad7f4_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_ad7f4_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_ad7f4_row1_col1" class="data row1 col1" >0.4912</td>
#       <td id="T_ad7f4_row1_col2" class="data row1 col2" >0.5541</td>
#       <td id="T_ad7f4_row1_col3" class="data row1 col3" >15.0942</td>
#       <td id="T_ad7f4_row1_col4" class="data row1 col4" >19.3103</td>
#       <td id="T_ad7f4_row1_col5" class="data row1 col5" >0.0318</td>
#       <td id="T_ad7f4_row1_col6" class="data row1 col6" >0.0316</td>
#       <td id="T_ad7f4_row1_col7" class="data row1 col7" >-0.4464</td>
#       <td id="T_ad7f4_row1_col8" class="data row1 col8" >0.3900</td>
#     </tr>
#     <tr>
#       <th id="T_ad7f4_level0_row2" class="row_heading level0 row2" >exp_smooth</th>
#       <td id="T_ad7f4_row2_col0" class="data row2 col0" >Exponential Smoothing</td>
#       <td id="T_ad7f4_row2_col1" class="data row2 col1" >0.4929</td>
#       <td id="T_ad7f4_row2_col2" class="data row2 col2" >0.5561</td>
#       <td id="T_ad7f4_row2_col3" class="data row2 col3" >15.1478</td>
#       <td id="T_ad7f4_row2_col4" class="data row2 col4" >19.3792</td>
#       <td id="T_ad7f4_row2_col5" class="data row2 col5" >0.0320</td>
#       <td id="T_ad7f4_row2_col6" class="data row2 col6" >0.0317</td>
#       <td id="T_ad7f4_row2_col7" class="data row

# %%
# compare models using OOP
exp.compare_models()
# Out:
# <style type="text/css">
# #T_ad509 th {
#   text-align: left;
# }
# #T_ad509_row0_col0, #T_ad509_row1_col0, #T_ad509_row1_col1, #T_ad509_row1_col2, #T_ad509_row1_col3, #T_ad509_row1_col4, #T_ad509_row1_col5, #T_ad509_row1_col6, #T_ad509_row1_col7, #T_ad509_row2_col0, #T_ad509_row2_col1, #T_ad509_row2_col2, #T_ad509_row2_col3, #T_ad509_row2_col4, #T_ad509_row2_col5, #T_ad509_row2_col6, #T_ad509_row2_col7, #T_ad509_row3_col0, #T_ad509_row3_col1, #T_ad509_row3_col2, #T_ad509_row3_col3, #T_ad509_row3_col4, #T_ad509_row3_col5, #T_ad509_row3_col6, #T_ad509_row3_col7, #T_ad509_row4_col0, #T_ad509_row4_col1, #T_ad509_row4_col2, #T_ad509_row4_col3, #T_ad509_row4_col4, #T_ad509_row4_col5, #T_ad509_row4_col6, #T_ad509_row4_col7, #T_ad509_row5_col0, #T_ad509_row5_col1, #T_ad509_row5_col2, #T_ad509_row5_col3, #T_ad509_row5_col4, #T_ad509_row5_col5, #T_ad509_row5_col6, #T_ad509_row5_col7, #T_ad509_row6_col0, #T_ad509_row6_col1, #T_ad509_row6_col2, #T_ad509_row6_col3, #T_ad509_row6_col4, #T_ad509_row6_col5, #T_ad509_row6_col6, #T_ad509_row6_col7, #T_ad509_row7_col0, #T_ad509_row7_col1, #T_ad509_row7_col2, #T_ad509_row7_col3, #T_ad509_row7_col4, #T_ad509_row7_col5, #T_ad509_row7_col6, #T_ad509_row7_col7, #T_ad509_row8_col0, #T_ad509_row8_col1, #T_ad509_row8_col2, #T_ad509_row8_col3, #T_ad509_row8_col4, #T_ad509_row8_col5, #T_ad509_row8_col6, #T_ad509_row8_col7, #T_ad509_row9_col0, #T_ad509_row9_col1, #T_ad509_row9_col2, #T_ad509_row9_col3, #T_ad509_row9_col4, #T_ad509_row9_col5, #T_ad509_row9_col6, #T_ad509_row9_col7, #T_ad509_row10_col0, #T_ad509_row10_col1, #T_ad509_row10_col2, #T_ad509_row10_col3, #T_ad509_row10_col4, #T_ad509_row10_col5, #T_ad509_row10_col6, #T_ad509_row10_col7, #T_ad509_row11_col0, #T_ad509_row11_col1, #T_ad509_row11_col2, #T_ad509_row11_col3, #T_ad509_row11_col4, #T_ad509_row11_col5, #T_ad509_row11_col6, #T_ad509_row11_col7, #T_ad509_row12_col0, #T_ad509_row12_col1, #T_ad509_row12_col2, #T_ad509_row12_col3, #T_ad509_row12_col4, #T_ad509_row12_col5, #T_ad509_row12_col6, #T_ad509_row12_col7, #T_ad509_row13_col0, #T_ad509_row13_col1, #T_ad509_row13_col2, #T_ad509_row13_col3, #T_ad509_row13_col4, #T_ad509_row13_col5, #T_ad509_row13_col6, #T_ad509_row13_col7, #T_ad509_row14_col0, #T_ad509_row14_col1, #T_ad509_row14_col2, #T_ad509_row14_col3, #T_ad509_row14_col4, #T_ad509_row14_col5, #T_ad509_row14_col6, #T_ad509_row14_col7, #T_ad509_row15_col0, #T_ad509_row15_col1, #T_ad509_row15_col2, #T_ad509_row15_col3, #T_ad509_row15_col4, #T_ad509_row15_col5, #T_ad509_row15_col6, #T_ad509_row15_col7, #T_ad509_row16_col0, #T_ad509_row16_col1, #T_ad509_row16_col2, #T_ad509_row16_col3, #T_ad509_row16_col4, #T_ad509_row16_col5, #T_ad509_row16_col6, #T_ad509_row16_col7, #T_ad509_row17_col0, #T_ad509_row17_col1, #T_ad509_row17_col2, #T_ad509_row17_col3, #T_ad509_row17_col4, #T_ad509_row17_col5, #T_ad509_row17_col6, #T_ad509_row17_col7, #T_ad509_row18_col0, #T_ad509_row18_col1, #T_ad509_row18_col2, #T_ad509_row18_col3, #T_ad509_row18_col4, #T_ad509_row18_col5, #T_ad509_row18_col6, #T_ad509_row18_col7, #T_ad509_row19_col0, #T_ad509_row19_col1, #T_ad509_row19_col2, #T_ad509_row19_col3, #T_ad509_row19_col4, #T_ad509_row19_col5, #T_ad509_row19_col6, #T_ad509_row19_col7, #T_ad509_row20_col0, #T_ad509_row20_col1, #T_ad509_row20_col2, #T_ad509_row20_col3, #T_ad509_row20_col4, #T_ad509_row20_col5, #T_ad509_row20_col6, #T_ad509_row20_col7, #T_ad509_row21_col0, #T_ad509_row21_col1, #T_ad509_row21_col2, #T_ad509_row21_col3, #T_ad509_row21_col4, #T_ad509_row21_col5, #T_ad509_row21_col6, #T_ad509_row21_col7, #T_ad509_row22_col0, #T_ad509_row22_col1, #T_ad509_row22_col2, #T_ad509_row22_col3, #T_ad509_row22_col4, #T_ad509_row22_col5, #T_ad509_row22_col6, #T_ad509_row22_col7, #T_ad509_row23_col0, #T_ad509_row23_col1, #T_ad509_row23_col2, #T_ad509_row23_col3, #T_ad509_row23_col4, #T_ad509_row23_col5, #T_ad509_row23_col6, #T_ad509_row23_col7, #T_ad509_row24_col0, #T_ad509_row24_col1, #T_ad509_row24_col2, #T_ad509_row24_col3, #T_ad509_row24_col4, #T_ad509_row24_col5, #T_ad509_row24_col6, #T_ad509_row24_col7, #T_ad509_row25_col0, ...
#   text-align: left;
# }
# #T_ad509_row0_col1, #T_ad509_row0_col2, #T_ad509_row0_col3, #T_ad509_row0_col4, #T_ad509_row0_col5, #T_ad509_row0_col6, #T_ad509_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ad509_row0_col8, #T_ad509_row1_col8, #T_ad509_row2_col8, #T_ad509_row3_col8, #T_ad509_row4_col8, #T_ad509_row5_col8, #T_ad509_row6_col8, #T_ad509_row7_col8, #T_ad509_row8_col8, #T_ad509_row9_col8, #T_ad509_row10_col8, #T_ad509_row11_col8, #T_ad509_row12_col8, #T_ad509_row13_col8, #T_ad509_row14_col8, #T_ad509_row15_col8, #T_ad509_row16_col8, #T_ad509_row17_col8, #T_ad509_row18_col8, #T_ad509_row19_col8, #T_ad509_row20_col8, #T_ad509_row21_col8, #T_ad509_row22_col8, #T_ad509_row23_col8, #T_ad509_row25_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ad509_row24_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ad509">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad509_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ad509_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ad509_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ad509_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ad509_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ad509_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ad509_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ad509_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_ad509_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad509_level0_row0" class="row_heading level0 row0" >stlf</th>
#       <td id="T_ad509_row0_col0" class="data row0 col0" >STLF</td>
#       <td id="T_ad509_row0_col1" class="data row0 col1" >0.4136</td>
#       <td id="T_ad509_row0_col2" class="data row0 col2" >0.4530</td>
#       <td id="T_ad509_row0_col3" class="data row0 col3" >12.7373</td>
#       <td id="T_ad509_row0_col4" class="data row0 col4" >15.8272</td>
#       <td id="T_ad509_row0_col5" class="data row0 col5" >0.0262</td>
#       <td id="T_ad509_row0_col6" class="data row0 col6" >0.0261</td>
#       <td id="T_ad509_row0_col7" class="data row0 col7" >0.2016</td>
#       <td id="T_ad509_row0_col8" class="data row0 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_ad509_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_ad509_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_ad509_row1_col1" class="data row1 col1" >0.4912</td>
#       <td id="T_ad509_row1_col2" class="data row1 col2" >0.5541</td>
#       <td id="T_ad509_row1_col3" class="data row1 col3" >15.0942</td>
#       <td id="T_ad509_row1_col4" class="data row1 col4" >19.3103</td>
#       <td id="T_ad509_row1_col5" class="data row1 col5" >0.0318</td>
#       <td id="T_ad509_row1_col6" class="data row1 col6" >0.0316</td>
#       <td id="T_ad509_row1_col7" class="data row1 col7" >-0.4464</td>
#       <td id="T_ad509_row1_col8" class="data row1 col8" >0.0167</td>
#     </tr>
#     <tr>
#       <th id="T_ad509_level0_row2" class="row_heading level0 row2" >exp_smooth</th>
#       <td id="T_ad509_row2_col0" class="data row2 col0" >Exponential Smoothing</td>
#       <td id="T_ad509_row2_col1" class="data row2 col1" >0.4929</td>
#       <td id="T_ad509_row2_col2" class="data row2 col2" >0.5561</td>
#       <td id="T_ad509_row2_col3" class="data row2 col3" >15.1478</td>
#       <td id="T_ad509_row2_col4" class="data row2 col4" >19.3792</td>
#       <td id="T_ad509_row2_col5" class="data row2 col5" >0.0320</td>
#       <td id="T_ad509_row2_col6" class="data row2 col6" >0.0317</td>
#       <td id="T_ad509_row2_col7" class="data row
# STLForecaster(sp=12)

# %%
# plot forecast
plot_model(best, plot = 'forecast')
